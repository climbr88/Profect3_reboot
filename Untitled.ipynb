# %%
import pandas as pd
import numpy as np

# %%
google=pd.read_csv('Resources/google_search_interest.csv')

# %%
google
# Out:
#             Category: All categories
# Day         bitcoin: (United States)
# 2020-08-07                        77
# 2020-08-08                        67
# 2020-08-09                        65
# 2020-08-10                        78
# ...                              ...
# 2020-10-29                        71
# 2020-10-30                        68
# 2020-10-31                        67
# 2020-11-01                        66
# 2020-11-02                        70
#
# [89 rows x 1 columns]

# %%
data = pd.read_csv('Resources/BTC_hist.csv')
data
# Out:
#            Date      Open*       High        Low    Close**          Volume  \
# 0      8-Nov-20  14,833.75  15,637.32  14,744.11  15,479.57  26,632,075,029
# 1      7-Nov-20  15,565.88  15,737.10  14,423.20  14,833.75  35,024,953,706
# 2      6-Nov-20  15,579.73  15,903.44  15,226.84  15,565.88  39,837,841,971
# 3      5-Nov-20  14,133.73  15,706.40  14,102.09  15,579.85  40,856,321,439
# 4      4-Nov-20  13,950.49  14,218.77  13,580.47  14,133.71  35,116,364,962
# ...         ...        ...        ...        ...        ...             ...
# 2747   2-May-13     116.38      125.6      92.28     105.21               0
# 2748   1-May-13        139     139.89     107.72     116.99               0
# 2749  30-Apr-13        144     146.93     134.05        139               0
# 2750  29-Apr-13     134.44     147.49        134     144.54               0
# 2751  28-Apr-13      135.3     135.98      132.1     134.21               0
#
#            Market Cap
# 0     286,955,182,899
# ...

# %%
pip install requests

# %%
from requests import Request, Session

from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json
import time

# %%
url = 'https://undefined/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'5000',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '3d5a6904-5cff-49fa-8b07-abb035d7b63d',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters, verify=False)
  data = json.loads(response.text)
  print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)
# Out:
# HTTPSConnectionPool(host='undefined', port=443): Max retries exceeded with url: /v1/cryptocurrency/listings/latest?start=1&limit=5000&convert=USD (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000018C539EA048>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed',))
